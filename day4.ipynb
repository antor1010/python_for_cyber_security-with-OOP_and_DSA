# %% [markdown]
# <a href="https://colab.research.google.com/github/antor1010/python_for_cyber_security-with-OOP_and_DSA/blob/main/day4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#arithmetic operator
a=8+2
b=8-2
c=8*2
d=8/2
e=8//2    #floor Division
f=9//2    #9//2 then output is 4 neglect .5
g=9%2     #Modulus 9%2 2*4=8 output is 1
h=8**2    # to the power 8^2 =64 & 2^2=4
print(a,b,c,d,e,f,g,h)
# Out:
# 10 6 16 4.0 4 4 1 64

# %%
x = 5
x += 3 #output 5+3=8
x -= 2 #output 8-2=6
x *= 4 #output 6*4=24
x /= 2 #output 24/2=12.0
print(x)
# Out:
# 12.0

# %%
x=3**2**2   #(3^4)
print(x)
# Out:
# 81

# %%
#Relational Operator
x=5
y=3
print(x>y)
print(x<y)
# Out:
# True
# False

# %%
x="Antor"
y="ANtor"
z="Antor"
print(x==y)
print(x==z)
# Out:
# False
# True

# %%
#user input
x=int(input("Enter your age:"))
print("Age",x)
# Out:
# Enter your age:18
# Age 18

# %%
x=str(input("Enter your name:"))
print("Name",x)
# Out:
# Enter your name:Antor
# Name Antor

# %%
x=float(input("Enter CGPA:"))
print("CGPA",x)
# Out:
# Enter CGPA:8.5
# CGPA 8.5

# %%
x=int(input())
sq=x**2
print(sq)
# Out:
# 4
# 16

# %%
#split and input
a,b,c,d=input().split()
print(d,c,a,b)
# Out:
# My name is Antor
# Antor is My name
